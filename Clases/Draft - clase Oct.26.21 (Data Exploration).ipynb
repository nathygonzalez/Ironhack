# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv ('data/nba.csv')

# %%
display(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Data Exploration

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
help (df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. versionchanged:: 1.0.0
#
#            Pass tuple or list to drop on multiple axes.
#            Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
# ...

# %%
df.dropna(axis=0, how='all')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.dropna(axis=0, how='all', inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Equipos

# %%
set (df['Team'])
# Out:
# {'Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Charlotte Hornets',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Detroit Pistons',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Indiana Pacers',
#  'Los Angeles Clippers',
#  'Los Angeles Lakers',
#  'Memphis Grizzlies',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Minnesota Timberwolves',
#  'New Orleans Pelicans',
#  'New York Knicks',
#  'Oklahoma City Thunder',
#  'Orlando Magic',
#  'Philadelphia 76ers',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Washington Wizards'}

# %%
df ['Team'].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
df['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Atlanta Hawks             15
# Houston Rockets           15
# Portland Trail Blazers    15
# Denver Nuggets            15
# San Antonio Spurs         15
# Oklahoma City Thunder     15
# Chicago Bulls             15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Phoenix Suns              15
# Philadelphia 76ers        15
# Charlotte Hornets         15
# Detroit Pistons           15
# Washington Wizards        15
# Dallas Mavericks          15
# Utah Jazz                 15
# Miami Heat                15
# Cleveland Cavaliers       15
# Boston Celtics            15
# Indiana Pacers            15
# Sacramento Kings          15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
df['Age'].mean()
# Out:
# 26.938730853391686

# %%
# Edad media por equipo

# %%
# %%time
df.groupby('Team').mean()['Age']
# Out:
# Wall time: 6.01 ms
# Team
# Atlanta Hawks             28.200000
# Boston Celtics            24.733333
# Brooklyn Nets             25.600000
# Charlotte Hornets         26.133333
# Chicago Bulls             27.400000
# Cleveland Cavaliers       29.533333
# Dallas Mavericks          29.733333
# Denver Nuggets            25.733333
# Detroit Pistons           26.200000
# Golden State Warriors     27.666667
# Houston Rockets           26.866667
# Indiana Pacers            26.400000
# Los Angeles Clippers      29.466667
# Los Angeles Lakers        27.533333
# Memphis Grizzlies         28.388889
# Miami Heat                28.933333
# Milwaukee Bucks           24.562500
# Minnesota Timberwolves    26.357143
# New Orleans Pelicans      26.894737
# New York Knicks           27.000000
# Oklahoma City Thunder     27.066667
# Orlando Magic             25.071429
# Philadelphia 76ers        24.600000
# Phoenix Suns              25.866667
# Portland Trail Blazers    25.066667
# ...

# %%
# %%time
df.groupby('Team')['Age'].mean()
# Out:
# Wall time: 4.03 ms
# Team
# Atlanta Hawks             28.200000
# Boston Celtics            24.733333
# Brooklyn Nets             25.600000
# Charlotte Hornets         26.133333
# Chicago Bulls             27.400000
# Cleveland Cavaliers       29.533333
# Dallas Mavericks          29.733333
# Denver Nuggets            25.733333
# Detroit Pistons           26.200000
# Golden State Warriors     27.666667
# Houston Rockets           26.866667
# Indiana Pacers            26.400000
# Los Angeles Clippers      29.466667
# Los Angeles Lakers        27.533333
# Memphis Grizzlies         28.388889
# Miami Heat                28.933333
# Milwaukee Bucks           24.562500
# Minnesota Timberwolves    26.357143
# New Orleans Pelicans      26.894737
# New York Knicks           27.000000
# Oklahoma City Thunder     27.066667
# Orlando Magic             25.071429
# Philadelphia 76ers        24.600000
# Phoenix Suns              25.866667
# Portland Trail Blazers    25.066667
# ...

# %%
df.groupby('Team')['Age'].mean().nsmallest(1)
# Out:
# Team
# Utah Jazz    24.466667
# Name: Age, dtype: float64

# %%
df.groupby('Team')['Age'].mean().nlargest(1)
# Out:
# Team
# San Antonio Spurs    31.6
# Name: Age, dtype: float64

# %%
df.groupby('Team')['Age'].mean().sort_values().head(1)
# Out:
# Team
# Utah Jazz    24.466667
# Name: Age, dtype: float64

# %%
df.groupby('Team')['Age'].mean().sort_values(ascending=True).head(1)
# Out:
# Team
# Utah Jazz    24.466667
# Name: Age, dtype: float64

# %%
df.nlargest(1,'Weight')['Team']
# Out:
# 405    Minnesota Timberwolves
# Name: Team, dtype: object

# %%
df.nlargest(1,'Age')['Team']
# Out:
# 298    San Antonio Spurs
# Name: Team, dtype: object

# %%
df.nlargest(3,'Salary')
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
#
#      Weight   College      Salary
# 109   212.0       NaN  25000000.0
# 169   250.0       NaN  22970500.0
# 33    240.0  Syracuse  22875000.0

# %%
df.groupby('Team').aggregate(lambda x: x.mean())
# Out:
#                            Number        Age      Weight        Salary
# Team
# Atlanta Hawks           19.000000  28.200000  221.266667  4.860197e+06
# Boston Celtics          31.866667  24.733333  219.466667  4.181505e+06
# Brooklyn Nets           18.266667  25.600000  215.600000  3.501898e+06
# Charlotte Hornets       17.133333  26.133333  220.400000  5.222728e+06
# Chicago Bulls           19.200000  27.400000  218.933333  5.785559e+06
# Cleveland Cavaliers     14.466667  29.533333  227.866667  7.642049e+06
# Dallas Mavericks        20.000000  29.733333  227.000000  4.746582e+06
# Denver Nuggets          15.266667  25.733333  217.533333  4.294424e+06
# Detroit Pistons         17.266667  26.200000  222.200000  4.477884e+06
# Golden State Warriors   20.866667  27.666667  224.600000  5.924600e+06
# Houston Rockets         14.666667  26.866667  220.333333  5.018868e+06
# Indiana Pacers          18.933333  26.400000  222.266667  4.450122e+06
# ...

# %%
df.groupby('Team')['Age'].agg(lambda x: x.mean())
# Out:
# Team
# Atlanta Hawks             28.200000
# Boston Celtics            24.733333
# Brooklyn Nets             25.600000
# Charlotte Hornets         26.133333
# Chicago Bulls             27.400000
# Cleveland Cavaliers       29.533333
# Dallas Mavericks          29.733333
# Denver Nuggets            25.733333
# Detroit Pistons           26.200000
# Golden State Warriors     27.666667
# Houston Rockets           26.866667
# Indiana Pacers            26.400000
# Los Angeles Clippers      29.466667
# Los Angeles Lakers        27.533333
# Memphis Grizzlies         28.388889
# Miami Heat                28.933333
# Milwaukee Bucks           24.562500
# Minnesota Timberwolves    26.357143
# New Orleans Pelicans      26.894737
# New York Knicks           27.000000
# Oklahoma City Thunder     27.066667
# Orlando Magic             25.071429
# Philadelphia 76ers        24.600000
# Phoenix Suns              25.866667
# Portland Trail Blazers    25.066667
# Sacramento Kings          26.800000
# ...

# %%
df.groupby('Team')['Age'].agg(np.mean)
# Out:
# Team
# Atlanta Hawks             28.200000
# Boston Celtics            24.733333
# Brooklyn Nets             25.600000
# Charlotte Hornets         26.133333
# Chicago Bulls             27.400000
# Cleveland Cavaliers       29.533333
# Dallas Mavericks          29.733333
# Denver Nuggets            25.733333
# Detroit Pistons           26.200000
# Golden State Warriors     27.666667
# Houston Rockets           26.866667
# Indiana Pacers            26.400000
# Los Angeles Clippers      29.466667
# Los Angeles Lakers        27.533333
# Memphis Grizzlies         28.388889
# Miami Heat                28.933333
# Milwaukee Bucks           24.562500
# Minnesota Timberwolves    26.357143
# New Orleans Pelicans      26.894737
# New York Knicks           27.000000
# Oklahoma City Thunder     27.066667
# Orlando Magic             25.071429
# Philadelphia 76ers        24.600000
# Phoenix Suns              25.866667
# Portland Trail Blazers    25.066667
# Sacramento Kings          26.800000
# ...

# %%
# Modificando estructuras

# %%
df ['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
df['Position'].map({'SG':'Escolta', 'SF': 'Alero', 'PG':'Base','PF':'Ala Pivot', 'C': 'Pivot'})
# Out:
# 0           Base
# 1          Alero
# 2        Escolta
# 3        Escolta
# 4      Ala Pivot
#          ...
# 452    Ala Pivot
# 453         Base
# 454         Base
# 455        Pivot
# 456        Pivot
# Name: Position, Length: 457, dtype: object

# %%
df['Position'] = df['Position'].map({'SG':'Escolta', 'SF': 'Alero', 'PG':'Base','PF':'Ala Pivot', 'C': 'Pivot'})

# %%
df
# Out:
#               Name            Team  Number   Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       Base  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0      Alero  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0    Escolta  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0    Escolta  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0  Ala Pivot  29.0   6-10   231.0
# ..             ...             ...     ...        ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0  Ala Pivot  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       Base  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       Base  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0      Pivot  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0      Pivot  26.0    7-0   231.0
#
#                College     Salary
# ...

# %%
df['Age'] = df['Age'].astype('int')

# %%
df
# Out:
#               Name            Team  Number   Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       Base   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0      Alero   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0    Escolta   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0    Escolta   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0  Ala Pivot   29   6-10   231.0
# ..             ...             ...     ...        ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0  Ala Pivot   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       Base   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       Base   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0      Pivot   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0      Pivot   26    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(3), int32(1), object(5)
# memory usage: 50.1+ KB

# %%
df['Height']
# Out:
# 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 452    6-10
# 453     6-3
# 454     6-1
# 455     7-3
# 456     7-0
# Name: Height, Length: 457, dtype: object

# %%
'6-2'.split('-')
# Out:
# ['6', '2']

# %%
'6-2'.split('-')[0]
# Out:
# '6'

# %%
float('6-2'.split('-')[0])*30.5 + float('6'.split('-')[0])*2.5
# Out:
# 198.0

# %%
df ['Altura'] = df ['Height'].apply(lambda x: float(x.split('-')[0])*30.5 + float(x.split('-')[0])*2.5)

# %%
df
# Out:
#               Name            Team  Number   Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       Base   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0      Alero   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0    Escolta   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0    Escolta   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0  Ala Pivot   29   6-10   231.0
# ..             ...             ...     ...        ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0  Ala Pivot   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       Base   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       Base   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0      Pivot   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0      Pivot   26    7-0   231.0
#
#                College     Salary  Altura
# ...

# %%
df['Altura'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Altura'].hist()[bins=20]
# Out:
#   File "<ipython-input-48-b31431eb60c8>", line 1
#     df['Altura'].hist()[bins=20]
#                             ^
# SyntaxError: invalid syntax

# %%
for pos in df['Position'].unique():
    df[df['Position'] == pos]['Altura'].hist()

# %%
import seaborn as sns

# %%
sns.catplot(data=df, x='Position', y='Altura', kind='box')

# %%
df.isna().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# Altura       0
# dtype: int64

# %%
df['College'].fillna('Unknown', inplace = True)

# %%
df['Salary']
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 452    2239800.0
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# Name: Salary, Length: 457, dtype: float64

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary      Altura
# count  457.000000  457.000000  457.000000  4.460000e+02  457.000000
# mean    17.678337   26.938731  221.522976  4.842684e+06  200.671772
# std     15.966090    4.404016   26.368343  5.229238e+06   10.015642
# min      0.000000   19.000000  161.000000  3.088800e+04  165.000000
# 25%      5.000000   24.000000  200.000000  1.044792e+06  198.000000
# 50%     13.000000   26.000000  220.000000  2.839073e+06  198.000000
# 75%     25.000000   30.000000  240.000000  6.500000e+06  198.000000
# max     99.000000   40.000000  307.000000  2.500000e+07  231.000000

# %%
df['Age'].quantile(0.50)
# Out:
# 26.0

# %%
df['Age'].median()
# Out:
# 26.0

# %%
df['Age'].quantile(0.10)
# Out:
# 22.0

# %%
pd.get_dumies(df['Position'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-d46f82940290> in <module>
# ----> 1 pd.get_dumies(df['Position'])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'get_dumies'

# %%
df.groupby('Team').apply(lambda x: x['Salary'].fillna(x['Salary'].mean))
# Out:
# Team
# Atlanta Hawks       309     2000000.0
#                     310     1304520.0
#                     311     2854940.0
#                     312    12000000.0
#                     313     1000000.0
#                               ...
# Washington Wizards  378     4662960.0
#                     379     2170465.0
#                     380     1100602.0
#                     381      200600.0
#                     382    15851950.0
# Name: Salary, Length: 457, dtype: object

# %%
# 28.Oct.21
# Pivot tables

# %%
df.groupby(['Team', 'Position'])['Name'].count()
# Out:
# Team                Position
# Atlanta Hawks       Ala Pivot    4
#                     Alero        2
#                     Base         2
#                     Escolta      4
#                     Pivot        3
#                                 ..
# Washington Wizards  Ala Pivot    2
#                     Alero        4
#                     Base         2
#                     Escolta      4
#                     Pivot        3
# Name: Name, Length: 149, dtype: int64

# %%
help(pd.crosstab)
# Out:
# Help on function crosstab in module pandas.core.reshape.pivot:
#
# crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name: str = 'All', dropna: bool = True, normalize=False) -> 'DataFrame'
#     Compute a simple cross tabulation of two (or more) factors. By default
#     computes a frequency table of the factors unless an array of values and an
#     aggregation function are passed.
#
#     Parameters
#     ----------
#     index : array-like, Series, or list of arrays/Series
#         Values to group by in the rows.
#     columns : array-like, Series, or list of arrays/Series
#         Values to group by in the columns.
#     values : array-like, optional
#         Array of values to aggregate according to the factors.
#         Requires `aggfunc` be specified.
#     rownames : sequence, default None
#         If passed, must match number of row arrays passed.
#     colnames : sequence, default None
# ...

# %%
# Para hacer counts con 2 variables, frequencias

pd.crosstab(df['Team'], df ['Position'])
# Out:
# Position                Ala Pivot  Alero  Base  Escolta  Pivot
# Team
# Atlanta Hawks                   4      2     2        4      3
# Boston Celtics                  3      1     4        4      3
# Brooklyn Nets                   4      0     3        6      2
# Charlotte Hornets               3      1     3        5      3
# Chicago Bulls                   5      2     2        4      2
# Cleveland Cavaliers             2      2     3        5      3
# Dallas Mavericks                4      2     4        2      3
# Denver Nuggets                  2      3     3        4      3
# Detroit Pistons                 2      4     4        2      3
# Golden State Warriors           2      5     2        3      3
# Houston Rockets                 4      3     2        4      2
# Indiana Pacers                  4      3     4        2      2
# Los Angeles Clippers            3      4     3        3      2
# Los Angeles Lakers              4      4     3        1      3
# ...

# %%
help(pd.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.reshape.pivot:
#
# pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False) -> 'DataFrame'
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects
#     (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     data : DataFrame
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
#     columns : column, Grouper, array, or list of the previous
# ...

# %%
pd.pivot_table (data=df,
                values='Salary',
                aggfunc= 'mean',
                columns = 'Position',
                index = 'Team')
# Out:
# Position                   Ala Pivot         Alero          Base  \
# Team
# Atlanta Hawks           5.988067e+06  3.000000e+06  4.881700e+06
# Boston Celtics          6.056987e+06  6.796117e+06  4.974652e+06
# Brooklyn Nets           3.576205e+06           NaN  2.915759e+06
# Charlotte Hornets       4.685770e+06  6.331404e+06  4.776152e+06
# Chicago Bulls           3.361007e+06  1.958160e+06  1.117153e+07
# Cleveland Cavaliers     1.394101e+07  1.195889e+07  6.551592e+06
# Dallas Mavericks        3.052835e+06  8.231051e+06  4.418183e+06
# Denver Nuggets          7.024978e+06  9.327590e+06  3.482413e+06
# Detroit Pistons         4.000000e+06  5.173600e+06  4.260003e+06
# Golden State Warriors   7.275312e+06  3.766367e+06  8.457256e+06
# Houston Rockets         1.755114e+06  3.381986e+06  3.343543e+06
# Indiana Pacers          2.064961e+06  7.624404e+06  4.054692e+06
# Los Angeles Clippers    6.655482e+06  3.662924e+06  8.509072e+06
# ...

# %%
pd.pivot_table (data=df,
                index = 'Team',
                values='Salary',
                columns = 'College',
                aggfunc= 'count',
                fill_value=0)
# Out:
# College                 Alabama  Arizona  Arizona State  Arkansas  Baylor  \
# Team
# Atlanta Hawks                 0        0              0         0       0
# Boston Celtics                0        0              0         0       0
# Brooklyn Nets                 0        1              0         0       0
# Charlotte Hornets             0        0              0         0       0
# Chicago Bulls                 0        0              0         1       0
# Cleveland Cavaliers           1        2              0         0       0
# Dallas Mavericks              0        0              0         0       0
# Denver Nuggets                0        0              0         0       0
# Detroit Pistons               0        1              0         0       0
# Golden State Warriors         0        1              0         0       0
# Houston Rockets               0        1              1         1       0
# Indiana Pacers                0        2              0         0       0
# ...

# %%
plt.plot (df['Altura'], df ['Weight'])

# %%
plt.scatter (df['Altura'], df ['Weight'])

# %%
sns.regplot(data=df, x='Altura', y = 'Weight')
# Out:
# <AxesSubplot:xlabel='Altura', ylabel='Weight'>

# %%
# Presupuesto

# %%
df.groupby('Team')['Salary'].sum().sort_values(ascending=False)
# Out:
# Team
# Cleveland Cavaliers       106988689.0
# Los Angeles Clippers       94854640.0
# Oklahoma City Thunder      93765298.0
# Golden State Warriors      88868997.0
# Chicago Bulls              86783378.0
# San Antonio Spurs          84442733.0
# New Orleans Pelicans       82750774.0
# Miami Heat                 82515673.0
# Charlotte Hornets          78340920.0
# Memphis Grizzlies          76550880.0
# Washington Wizards         76328636.0
# Houston Rockets            75283021.0
# New York Knicks            73303898.0
# Atlanta Hawks              72902950.0
# Los Angeles Lakers         71770431.0
# Sacramento Kings           71683666.0
# Dallas Mavericks           71198732.0
# Toronto Raptors            71117611.0
# Milwaukee Bucks            69603517.0
# Detroit Pistons            67168263.0
# Indiana Pacers             66751826.0
# Phoenix Suns               63445135.0
# Utah Jazz                  63060091.0
# Orlando Magic              60161470.0
# ...

# %%
df2 = df.set_index('Name')
df2.head(3)
# Out:
#                          Team  Number Position  Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0     Base   25    6-2   180.0
# Jae Crowder    Boston Celtics    99.0    Alero   25    6-6   235.0
# John Holland   Boston Celtics    30.0  Escolta   27    6-5   205.0
#
#                          College     Salary  Altura
# Name
# Avery Bradley              Texas  7730337.0   198.0
# Jae Crowder            Marquette  6796117.0   198.0
# John Holland   Boston University        NaN   198.0

# %%
df2.loc['Avery Bradley']
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position              Base
# Age                     25
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Altura               198.0
# Name: Avery Bradley, dtype: object

# %%
df2.reset_index

# %%
presupuesto = df.groupby('Team')['Salary'].sum().reset_index()
presupuesto
# Out:
#                       Team       Salary
# 0            Atlanta Hawks   72902950.0
# 1           Boston Celtics   58541068.0
# 2            Brooklyn Nets   52528475.0
# 3        Charlotte Hornets   78340920.0
# 4            Chicago Bulls   86783378.0
# 5      Cleveland Cavaliers  106988689.0
# 6         Dallas Mavericks   71198732.0
# 7           Denver Nuggets   60121930.0
# 8          Detroit Pistons   67168263.0
# 9    Golden State Warriors   88868997.0
# 10         Houston Rockets   75283021.0
# 11          Indiana Pacers   66751826.0
# 12    Los Angeles Clippers   94854640.0
# 13      Los Angeles Lakers   71770431.0
# 14       Memphis Grizzlies   76550880.0
# 15              Miami Heat   82515673.0
# 16         Milwaukee Bucks   69603517.0
# 17  Minnesota Timberwolves   59709697.0
# 18    New Orleans Pelicans   82750774.0
# 19         New York Knicks   73303898.0
# 20   Oklahoma City Thunder   93765298.0
# 21           Orlando Magic   60161470.0
# ...

# %%
pd.merge(df,presupuesto, on='Team')
# Out:
#               Name            Team  Number   Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       Base   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0      Alero   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0    Escolta   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0    Escolta   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0  Ala Pivot   29   6-10   231.0
# ..             ...             ...     ...        ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0  Ala Pivot   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       Base   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       Base   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0      Pivot   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0      Pivot   26    7-0   231.0
#
#                College   Salary_x  Altura    Salary_y
# ...

# %%
df2 = pd.merge(df,presupuesto, on='Team')

# %%
df2.columns =

# %%
df2.rename(columns=('College': 'Procedencia'))

# %%
# Melt

# %%
lf = pd.read_csv('data/life_expectancy_years.csv')

# %%
lf
# Out:
#                  country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0            Afghanistan  28,2  28,2  28,2  28,2  28,2  28,2  28,1  28,1
# 1                Albania  35,4  35,4  35,4  35,4  35,4  35,4  35,4  35,4
# 2                Algeria  28,8  28,8  28,8  28,8  28,8  28,8  28,8  28,8
# 3                 Angola    27    27    27    27    27    27    27    27
# 4    Antigua and Barbuda  33,5  33,5  33,5  33,5  33,5  33,5  33,5  33,5
# ..                   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 179            Venezuela  32,2  32,2  32,2  32,2  32,2  32,2  32,2  32,2
# 180              Vietnam    32    32    32    32    32    32    32    32
# 181                Yemen  23,4  23,4  23,4  23,4  23,4  23,4  23,4  23,4
# 182               Zambia  32,6  32,6  32,6  32,6  32,6  32,6  32,6  32,6
# 183             Zimbabwe  33,7  33,7  33,7  33,7  33,7  33,7  33,7  33,7
#
#      1808  ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# ...

# %%
help(pd.melt)
# Out:
# Help on function melt in module pandas.core.reshape.melt:
#
# melt(frame: 'DataFrame', id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index: bool = True) -> 'DataFrame'
#     Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
#     This function is useful to massage a DataFrame into a format where one
#     or more columns are identifier variables (`id_vars`), while all other
#     columns, considered measured variables (`value_vars`), are "unpivoted" to
#     the row axis, leaving just two non-identifier columns, 'variable' and
#     'value'.
#
#     Parameters
#     ----------
#     id_vars : tuple, list, or ndarray, optional
#         Column(s) to use as identifier variables.
#     value_vars : tuple, list, or ndarray, optional
#         Column(s) to unpivot. If not specified, uses all columns that
#         are not set as `id_vars`.
#     var_name : scalar
# ...

# %%
life_expectancy = pd.melt(lf, id_vars='country', var_name ='Year', value_name='Life expectancy')
life_expectancy
# Out:
#                    country  Year Life expectancy
# 0              Afghanistan  1800            28,2
# 1                  Albania  1800            35,4
# 2                  Algeria  1800            28,8
# 3                   Angola  1800              27
# 4      Antigua and Barbuda  1800            33,5
# ...                    ...   ...             ...
# 40291            Venezuela  2018            75,9
# 40292              Vietnam  2018            74,9
# 40293                Yemen  2018            67,1
# 40294               Zambia  2018            59,5
# 40295             Zimbabwe  2018            60,2
#
# [40296 rows x 3 columns]

# %%
life_expectancy.pivot_table(data=life_expectancy,
                            index ='country',
                            columns='Year',
                            values='Life expectancy',
                            aggfun='sum')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-41ef60ff8e0b> in <module>
# ----> 1 life_expectancy.pivot_table(data=life_expectancy,
#       2                             index ='country',
#       3                             columns='Year',
#       4                             values='Life expectancy',
#       5                             aggfun='sum')
#
# TypeError: pivot_table() got an unexpected keyword argument 'data'

# %%
df2['Name'].str.startswith('John')
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# Name: Name, Length: 457, dtype: bool

# %%
df2['Name'].str.startswith('John').sum()
# Out:
# 5

# %%
df2[df2['Name'].str.startswith('John')]
# Out:
#                     Name                Team  Number   Position  Age Height  \
# 2           John Holland      Boston Celtics    30.0    Escolta   27    6-5
# 126         John Jenkins        Phoenix Suns    23.0    Escolta   25    6-4
# 216          John Henson     Milwaukee Bucks    31.0  Ala Pivot   25   6-11
# 222  Johnny O'Bryant III     Milwaukee Bucks    77.0  Ala Pivot   23    6-9
# 382            John Wall  Washington Wizards     2.0       Base   25    6-4
#
#      Weight            College    Salary_x  Altura    Salary_y
# 2     205.0  Boston University         NaN   198.0  58541068.0
# 126   215.0         Vanderbilt    981348.0   198.0  63445135.0
# 216   229.0     North Carolina   2943221.0   198.0  69603517.0
# 222   257.0                LSU    845059.0   198.0  69603517.0
# 382   195.0           Kentucky  15851950.0   198.0  76328636.0

# %%
df2['Name'].str.upper()
# Out:
# 0      AVERY BRADLEY
# 1        JAE CROWDER
# 2       JOHN HOLLAND
# 3        R.J. HUNTER
# 4      JONAS JEREBKO
#            ...
# 452       TREY LYLES
# 453     SHELVIN MACK
# 454        RAUL NETO
# 455     TIBOR PLEISS
# 456      JEFF WITHEY
# Name: Name, Length: 457, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary_x  446 non-null    float64
#  9   Altura    457 non-null    float64
#  10  Salary_y  457 non-null    float64
# dtypes: float64(5), int32(1), object(5)
# memory usage: 41.1+ KB

# %%
help(pd.to_datetime)
# Out:
# Help on function to_datetime in module pandas.core.tools.datetimes:
#
# to_datetime(arg: Union[~DatetimeScalar, List, Tuple, ~ArrayLike, ForwardRef('Series')], errors: str = 'raise', dayfirst: bool = False, yearfirst: bool = False, utc: Union[bool, NoneType] = None, format: Union[str, NoneType] = None, exact: bool = True, unit: Union[str, NoneType] = None, infer_datetime_format: bool = False, origin='unix', cache: bool = True) -> Union[pandas.core.indexes.datetimes.DatetimeIndex, ForwardRef('Series'), ~DatetimeScalar, ForwardRef('NaTType')]
#     Convert argument to datetime.
#
#     Parameters
#     ----------
#     arg : int, float, str, datetime, list, tuple, 1-d array, Series, DataFrame/dict-like
#         The object to convert to a datetime.
#     errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#         - If 'raise', then invalid parsing will raise an exception.
#         - If 'coerce', then invalid parsing will be set as NaT.
# ...

# %%
help(pd.cut)
# Out:
# Help on function cut in module pandas.core.reshape.tile:
#
# cut(x, bins, right: bool = True, labels=None, retbins: bool = False, precision: int = 3, include_lowest: bool = False, duplicates: str = 'raise', ordered: bool = True)
#     Bin values into discrete intervals.
#
#     Use `cut` when you need to segment and sort data values into bins. This
#     function is also useful for going from a continuous variable to a
#     categorical variable. For example, `cut` could convert ages to groups of
#     age ranges. Supports binning into an equal number of bins, or a
#     pre-specified array of bins.
#
#     Parameters
#     ----------
#     x : array-like
#         The input array to be binned. Must be 1-dimensional.
#     bins : int, sequence of scalars, or IntervalIndex
#         The criteria to bin by.
#
#         * int : Defines the number of equal-width bins in the range of `x`. The
#           range of `x` is extended by .1% on each side to include the minimum
# ...

# %%
pd.cut(df2['Altura'], [0,180,200,250])
# Out:
# 0      (180, 200]
# 1      (180, 200]
# 2      (180, 200]
# 3      (180, 200]
# 4      (180, 200]
#           ...
# 452    (180, 200]
# 453    (180, 200]
# 454    (180, 200]
# 455    (200, 250]
# 456    (200, 250]
# Name: Altura, Length: 457, dtype: category
# Categories (3, interval[int64]): [(0, 180] < (180, 200] < (200, 250]]

# %%
pd.cut(df2['Altura'], [0,180,200,250], labels=['Altura media', 'Alto', 'Muy alto'])
# Out:
# 0          Alto
# 1          Alto
# 2          Alto
# 3          Alto
# 4          Alto
#          ...
# 452        Alto
# 453        Alto
# 454        Alto
# 455    Muy alto
# 456    Muy alto
# Name: Altura, Length: 457, dtype: category
# Categories (3, object): ['Altura media' < 'Alto' < 'Muy alto']

# %%
pd.cut(df2['Altura'], [0,180,200,250], labels=['Altura media', 'Alto', 'Muy alto']).value_counts()
# Out:
# Alto            412
# Muy alto         41
# Altura media      4
# Name: Altura, dtype: int64

# %%
Altura txt = pd.cut(df2['Altura'], [0,180,200,250], labels=['Altura media', 'Alto', 'Muy alto'])

# %% [markdown]
# # DRAFT PROJECT 2

# %%
# Checking how many of each country I have - ok
df["Country"].value_counts()

# %%
# Deleting the empty space at the beginning - STOP
df = df["Country"].str.strip()
df

# %%
# Standardizing lower/upper cases/titles - STOP
df = df["Country"].str.title()
df

# %%
# I'm still seeing some NaN, so I'm replacing them - OK
df['Country'].fillna("Unknown",inplace = True)

# %%
# - STOP
df.sort_values ('Country', ascending = False, inplace = True)
df

# %%
# Creating a list with the 30 most relevant countries
relevantcountries = df['Country'].value_counts().nlargest(30).index.to_list()

# %%
df['Fatal (Y/N)'].plot.pie(subplots=True, figsize=(11, 6))

# %%
sharks["Type"].value_counts().plot(kind = "barh")

# %%
df.columns
